# %%
import os

import pandas as pd
import tiktoken

from graphrag.config.enums import ModelType
from graphrag.config.models.language_model_config import LanguageModelConfig
from graphrag.language_model.manager import ModelManager
from graphrag.query.indexer_adapters import (
    read_indexer_communities,
    read_indexer_entities,
    read_indexer_reports,
)
from graphrag.query.structured_search.global_search.community_context import (
    GlobalCommunityContext,
)
from graphrag.query.structured_search.global_search.search import GlobalSearch

# %%
from dotenv import load_dotenv
load_dotenv("../../.env")
# Out:
# True

# %%
api_key = os.environ["AZURE_OPENAI_API_KEY"]
llm_model = "gpt-4.1-mini" #os.environ["GRAPHRAG_LLM_MODEL"]

config = LanguageModelConfig(
    api_key=api_key,
    type=ModelType.AzureOpenAIChat,
    api_base=os.environ['AZURE_OPENAI_ENDPOINT'],
    api_version="2025-04-01-preview",
    deployment_name=llm_model,
    model=llm_model,
    max_retries=20,
)
model = ModelManager().get_or_create_chat_model(
    name="global_search",
    model_type=ModelType.AzureOpenAIChat,
    config=config,
)

token_encoder = tiktoken.encoding_for_model(llm_model)
# Out:
# Model config based on fnllm is deprecated and will be removed in GraphRAG v3, please use ModelType.Chat or ModelType.Embedding instead to switch to LiteLLM config.

# %%
# parquet files generated from indexing pipeline
INPUT_DIR = "../output"
COMMUNITY_TABLE = "communities"
COMMUNITY_REPORT_TABLE = "community_reports"
ENTITY_TABLE = "entities"

# community level in the Leiden community hierarchy from which we will load the community reports
# higher value means we use reports from more fine-grained communities (at the cost of higher computation cost)
COMMUNITY_LEVEL = 2

# %%
community_df = pd.read_parquet(f"{INPUT_DIR}/{COMMUNITY_TABLE}.parquet")
entity_df = pd.read_parquet(f"{INPUT_DIR}/{ENTITY_TABLE}.parquet")
report_df = pd.read_parquet(f"{INPUT_DIR}/{COMMUNITY_REPORT_TABLE}.parquet")

communities = read_indexer_communities(community_df, report_df)
reports = read_indexer_reports(report_df, community_df, COMMUNITY_LEVEL)
entities = read_indexer_entities(entity_df, community_df, COMMUNITY_LEVEL)

print(f"Total report count: {len(report_df)}")
print(
    f"Report count after filtering by community level {COMMUNITY_LEVEL}: {len(reports)}"
)

report_df.head()
# Out:
# Total report count: 39
# Report count after filtering by community level 2: 39
#                                  id  human_readable_id  community  level  \
# 0  3712188d005449499a94b1ee5d9d5ec3                 12         12      1
# 1  5f053034f92b4f7698d3a8c904fcd7f7                 13         13      1
# 2  945c3298634d4cdfa91f6d0bf17db51e                 14         14      1
# 3  a180a897c33a4a06bd7f04dc5d9d818d                 15         15      1
# 4  845c28fbf6294a3caa5139cd821cf43c                 16         16      1
#
#    parent children                                              title  \
# 0       0       []        Gangnam Technology and Software Events 2025
# 1       0       []           AI·ICT 기술·산업전망 컨퍼런스 and Jung-gu District
# 2       0       []  Seoul Technology Events Community: STK 2025, M...
# 3       0       []  Cloud & AI Infrastructure Summit 2025 Korea an...
# 4       1       []  Li Qiang, China, and the 2025 World AI Conference
#
#                                              summary  \
# 0  This community centers on Gangnam, a prominent...
# 1  This community centers on the AI·ICT 기술·산업전망 컨...
# 2  This community centers around Seoul, South Kor...
# 3  This community centers on the Cloud & AI Infra...
# 4  This community centers on the 2025 World AI Co...
#
#                                         full_content  rank  \
# 0  # Gangnam Technology and Software Events 2025\...   6.5
# 1  # AI·ICT 기술·산업전망 컨퍼런스 and Jung-gu District\n\n...   4.0
# 2  # Seoul Technology Events Community: STK 2025,...   6.5
# 3  # Cloud & AI Infrastructure Summit 2025 Korea ...   4.0
# 4  # Li Qiang, China, and the 2025 World AI Confe...   8.5
#
#                                   rating_explanation  \
# 0  The impact severity rating reflects the commun...
# 1  The impact severity rating is moderate due to ...
# 2  The impact severity rating reflects Seoul's si...
# 3  The impact severity rating is moderate due to ...
# 4  The impact severity rating is high due to the ...
#
#                                             findings  \
# 0  [{'explanation': 'Gangnam district in Seoul is...
# 1  [{'explanation': 'The AI·ICT 기술·산업전망 컨퍼런스 is a...
# 2  [{'explanation': 'Seoul is the primary entity ...
# 3  [{'explanation': 'The Cloud & AI Infrastructur...
# 4  [{'explanation': 'Li Qiang, as the Premier of ...
#
#                                    full_content_json      period  size
# 0  {\n    "title": "Gangnam Technology and Softwa...  2025-11-20     4
# 1  {\n    "title": "AI·ICT 기술·산업전망 컨퍼런스 and Jung-...  2025-11-20     2
# 2  {\n    "title": "Seoul Technology Events Commu...  2025-11-20     4
# 3  {\n    "title": "Cloud & AI Infrastructure Sum...  2025-11-20     2
# 4  {\n    "title": "Li Qiang, China, and the 2025...  2025-11-20     3

# %%
context_builder = GlobalCommunityContext(
    community_reports=reports,
    communities=communities,
    entities=entities,  # default to None if you don't want to use community weights for ranking
)

# %%
context_builder_params = {
    "use_community_summary": False,  # False means using full community reports. True means using community short summaries.
    "shuffle_data": True,
    "include_community_rank": True,
    "min_community_rank": 0,
    "community_rank_name": "rank",
    "include_community_weight": True,
    "community_weight_name": "occurrence weight",
    "normalize_community_weight": True,
    "max_tokens": 12_000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 5000)
    "context_name": "Reports",
}

map_llm_params = {
    "max_tokens": 1000,
    "temperature": 0.0,
    "response_format": {"type": "json_object"},
}

reduce_llm_params = {
    "max_tokens": 2000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 1000-1500)
    "temperature": 0.0,
}

# %%
search_engine = GlobalSearch(
    model=model,
    context_builder=context_builder,
    max_data_tokens=12_000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 5000)
    map_llm_params=map_llm_params,
    reduce_llm_params=reduce_llm_params,
    allow_general_knowledge=False,  # set this to True will add instruction to encourage the LLM to incorporate general knowledge in the response, which may increase hallucinations, but could be useful in some use cases.
    json_mode=True,  # set this to False if your LLM model does not support JSON mode.
    context_builder_params=context_builder_params,
    concurrent_coroutines=32,
    response_type="multiple paragraphs",  # free form text describing the response type and format, can be anything, e.g. prioritized list, single paragraph, multiple paragraphs, multiple-page report
)

# %%
prompt = """ AI산업의 트랜드와 전망에 대해 아래 보고서 양식으로 작성해줘. 

# 보고서 항목
AI 산업의 트랜드
- 산업 변화
- 시장 변화
- 위험 요소

# 언어 및 스타일
- 한국어로 간결하고 명확하게 작성하십시오
- 최대한 객관적이되 통찰력 있는 시각으로 작성하십시오.
"""

# %%
result = await search_engine.search(prompt)

print(result.response)
# Out:
# # AI 산업의 트렌드와 전망 보고서
#
# ## AI 산업의 트렌드
#
# ### 산업 변화
# AI 산업은 대형 기술 기업과 스타트업 간의 인재 경쟁이 심화되면서 빠르게 재편되고 있습니다. 마이크로소프트, 아마존, 구글 등 대형 IT 기업들은 첨단 AI 모델 개발과 함께 스타트업 창업자 및 연구진을 직접 영입하는 ‘역인수합병(reverse acquihire)’ 전략을 적극 활용하고 있습니다. 이러한 전략은 혁신 동력의 집중을 촉진하는 한편, 스타트업 생태계의 다양성 감소와 지속 가능성 약화라는 부작용을 초래할 수 있습니다.
#
# 또한, 오픈소스 AI 모델의 확산이 중요한 산업 트렌드로 자리 잡고 있습니다. 오픈AI의 GPT-OSS 시리즈와 중국의 Zhipu AI가 공개한 GLM-4.5 모델 등은 글로벌 연구자 및 개발자 커뮤니티의 협업과 혁신을 촉진하며 AI 기술의 민주화와 경쟁 심화를 반영합니다. 하드웨어 측면에서는 NVIDIA H100 GPU와 같은 첨단 장비가 AI 모델의 효율적 학습과 성능 향상을 가능하게 하여 산업 전반의 기술 고도화를 견인하고 있습니다.
#
# 정부 주도의 대규모 AI 플랫폼 구축도 산업 변화의 핵심입니다. 미국 정부는 GSA를 중심으로 USAi 플랫폼을 통해 연방 기관에 안전한 생성형 AI 도구를 제공하며, Anthropic, Google 등 선도 기업과 협력해 공공 부문 AI 확산을 가속화하고 있습니다. 이와 함께, 메타, 마이크로소프트, 아마존 등은 자체 AI 모델 개발과 스타트업 인수·합병을 통해 인재 확보와 기술 경쟁력 강화를 도모하고 있습니다 [Data: Reports (27, 29, 9, 4, 34, 37, 6, 10, 11, 36, 35)].
#
# ### 시장 변화
# AI 시장은 공공 및 민간 부문에서의 AI 도입이 동시에 가속화되고 있습니다. 미국 연방 정부는 USAi 플랫폼을 통해 AI 도구를 저렴한 비용으로 제공하며 다양한 기관에서 AI 실험과 도입을 촉진하고 있습니다. 구글은 Gemini AI 생태계를 통해 고도화된 AI 모델과 구독형 서비스 모델을 제공하며 시장 점유율 확대를 노리고 있습니다. 메타는 AI 스타트업에 대규모 투자를 진행하며 AI 연구개발 역량을 강화하고 있습니다.
#
# 한편, 중국은 AI를 글로벌 공공재로 추진하며 2025년 세계 AI 협력기구 설립을 제안하는 등 국제 협력과 표준화에 주도적 역할을 하고 있습니다. 아시아 지역에서는 서울 강남과 중구 등 주요 도심에서 AI 및 ICT 관련 대규모 컨퍼런스와 전시회가 개최되어 지역 기술 생태계 활성화에 기여하고 있습니다.
#
# 이와 같은 시장 변화는 AI 기술의 빠른 확산과 함께 인재 확보 경쟁, 비용 효율성, 글로벌 협력의 중요성을 부각시키고 있으며, AI 산업이 공공과 민간, 지역과 글로벌 차원에서 통합된 생태계를 형성하고 있음을 보여줍니다 [Data: Reports (9, 4, 19, 34, 1, 26, 12, 13, 5, 32, 31)].
#
# ### 위험 요소
# AI 산업은 인재 경쟁 심화, 기술 독점, 안전성과 윤리 문제 등 다양한 위험 요소에 직면해 있습니다. 대형 IT 기업들의 인재 쟁탈전은 스타트업 생태계의 지속 가능성을 위협하며, 인수합병 과정에서 내부 갈등과 인력 이탈이 발생할 수 있습니다. 예를 들어, 구글의 Windsurf 인재 인수 사례는 조직 내 불만과 혼란을 야기한 바 있습니다.
#
# AI 모델의 안전성 문제도 중요한 위험 요소입니다. 미국 연방 법원에서 Tesla Autopilot 관련 사고 판결이 부각되었으며, AI 응답 품질과 윤리성 개선 요구가 지속되고 있습니다. 글로벌 차원에서는 중국 정부의 AI 협력기구 제안과 OECD의 AI 개방성 보고서가 AI 거버넌스와 규제 필요성을 강조하지만, 국제 사회 전반에 걸친 통일된 규범과 윤리 기준 마련은 아직 진행 중입니다.
#
# 또한, AI 인재의 높은 이직률과 인재 유동성 증가는 경쟁 심화와 인재 확보의 어려움을 시사하며, 고가의 라이선스 비용과 기술 집중은 중소기업과 스타트업의 혁신 역량을 저해할 수 있습니다. 이러한 위험 요소들은 AI 산업의 지속 가능한 발전을 위해 기술적, 정책적 대응과 신뢰 구축, 규제 체계 마련이 필수적임을 시사합니다 [Data: Reports (9, 7, 4, 19, 27, 29, 35, 6, 36, 8, 17, 18, 1)].
#
# ---
#
# 본 보고서는 AI 산업의 현재 트렌드와 시장 변화, 그리고 내재된 위험 요소를 종합적으로 분석하여, AI 산업이 앞으로도 혁신과 성장의 중심에 있으면서도 지속 가능성과 윤리적 책임을 함께 고려해야 함을 강조합니다. AI 기술의 민주화와 글로벌 협력 강화, 그리고 공공 부문과 민간 부문의 균형 있는 발전이 향후 AI 산업의 건강한 생태계 조성에 중요한 역할을 할 것입니다.

# %%
# inspect the data used to build the context for the LLM responses
result.context_data["reports"]
# Out:
#     id                                              title  occurrence weight  \
# 0    6         OpenAI and Its Advanced AI Model Ecosystem           1.000000
# 1   27  Microsoft, Amazon, and Silicon Valley AI Talen...           0.454545
# 2    2  Google Cloud AI Agent Ecosystem Featuring Gemi...           0.272727
# 3   38  GLM-4.5 and Zupo AI AI Model Benchmarking Comm...           0.272727
# 4   14  Seoul Technology Events Community: STK 2025, M...           0.272727
# 5   35  U.S. Federal Acquisition Service and USAi Plat...           0.090909
# 6   22  Google's Gemini AI Platform and Its Agent Ecos...           0.090909
# 7   29                 Inflection AI and Mustafa Suleyman           0.090909
# 8   20      Data Engineering Agent and BigQuery Community           0.090909
# 9    9  GSA USAi Platform and Leading AI Providers Ant...           0.818182
# 10   4  Meta, Microsoft, and AI Talent Dynamics in Sil...           0.636364
# 11  34  Anthropic, GSA, and USAi in U.S. Federal AI St...           0.363636
# 12   7      OECD, SPRi, and Global AI Governance Entities           0.272727
# 13  21  Google Cloud AI Agent Ecosystem: MCP, Looker, ...           0.181818
# 14  37           Zhipu AI and GLM-4.5 AI Models Community           0.181818
# 15  19  Maimai and China Daily on AI Talent Mobility i...           0.090909
# 16  10  Zhipu AI and GLM-4.5 Open Source AI Models Com...           0.363636
# 17  17    China and the World AI Cooperation Organization           0.272727
# 18  24  Claude Opus 4.1 AI Model and GitHub Benchmarki...           0.272727
# 19  30  Las Vegas Technology Conferences: CES, Microso...           0.272727
# 20  23  JULES AI Coding Agent and Google AI Subscripti...           0.181818
# 21  33  San Francisco Technology Conferences: Microsof...           0.181818
# 22  11  MoimAct's MolmoAct-7B and NVIDIA H100 GPU AI T...           0.090909
# 23  18  AI Global Governance Action Plan and Internati...           0.090909
# 24  26  Meta Platforms and Scale AI AI Innovation Comm...           0.454545
# 25   1  China's Leadership in Global AI Governance and...           0.272727
# 26  28  DINOv3 and Its Applications in Environmental M...           0.272727
# 27   0     Seoul Technology Events and District Hubs 2025           0.272727
# 28   3  Claude Opus AI Models and GitHub Benchmarking ...           0.272727
# 29  25  Claude Opus 4, Claude Opus 4.1, and Claude Son...           0.090909
# 30  15  Cloud & AI Infrastructure Summit 2025 Korea an...           0.090909
# 31  36                     Google and Gemini AI Ecosystem           0.818182
# 32   5  Apple's American Manufacturing Program and US ...           0.636364
# 33  32  United States Technology and AI Ecosystem with...           0.363636
# 34  31  Apple's American Manufacturing Program and Key...           0.181818
# 35  16  Li Qiang, China, and the 2025 World AI Conference           0.181818
# 36  12        Gangnam Technology and Software Events 2025           0.181818
# 37   8  Reverse-Acquihire Trend and Decibel Venture Ca...           0.090909
# 38  13           AI·ICT 기술·산업전망 컨퍼런스 and Jung-gu District           0.090909
#
#                                               content  rank
# 0   # OpenAI and Its Advanced AI Model Ecosystem\n...   8.5
# 1   # Microsoft, Amazon, and Silicon Valley AI Tal...   7.5
# 2   # Google Cloud AI Agent Ecosystem Featuring Ge...   8.5
# 3   # GLM-4.5 and Zupo AI AI Model Benchmarking Co...   7.2
# 4   # Seoul Technology Events Community: STK 2025,...   6.5
# 5   # U.S. Federal Acquisition Service and USAi Pl...   7.5
# 6   # Google's Gemini AI Platform and Its Agent Ec...   7.5
# 7   # Inflection AI and Mustafa Suleyman\n\nThis c...   7.5
# 8   # Data Engineering Agent and BigQuery Communit...   6.5
# 9   # GSA USAi Platform and Leading AI Providers A...   8.5
# 10  # Meta, Microsoft, and AI Talent Dynamics in S...   8.5
# 11  # Anthropic, GSA, and USAi in U.S. Federal AI ...   8.5
# 12  # OECD, SPRi, and Global AI Governance Entitie...   7.5
# 13  # Google Cloud AI Agent Ecosystem: MCP, Looker...   8.5
# 14  # Zhipu AI and GLM-4.5 AI Models Community\n\n...   7.5
# 15  # Maimai and China Daily on AI Talent Mobility...   6.5
# 16  # Zhipu AI and GLM-4.5 Open Source AI Models C...   7.5
# 17  # China and the World AI Cooperation Organizat...   8.5
# 18  # Claude Opus 4.1 AI Model and GitHub Benchmar...   7.5
# 19  # Las Vegas Technology Conferences: CES, Micro...   7.5
# 20  # JULES AI Coding Agent and Google AI Subscrip...   7.5
# 21  # San Francisco Technology Conferences: Micros...   6.5
# 22  # MoimAct's MolmoAct-7B and NVIDIA H100 GPU AI...   7.5
# 23  # AI Global Governance Action Plan and Interna...   7.5
# 24  # Meta Platforms and Scale AI AI Innovation Co...   8.5
# 25  # China's Leadership in Global AI Governance a...   8.5
# 26  # DINOv3 and Its Applications in Environmental...   7.5
# 27  # Seoul Technology Events and District Hubs 20...   7.5
# 28  # Claude Opus AI Models and GitHub Benchmarkin...   6.5
# 29  # Claude Opus 4, Claude Opus 4.1, and Claude S...   4.2
# 30  # Cloud & AI Infrastructure Summit 2025 Korea ...   4.0
# 31  # Google and Gemini AI Ecosystem\n\nThis commu...   8.5
# 32  # Apple's American Manufacturing Program and U...   8.5
# 33  # United States Technology and AI Ecosystem wi...   8.5
# 34  # Apple's American Manufacturing Program and K...   8.5
# 35  # Li Qiang, China, and the 2025 World AI Confe...   8.5
# 36  # Gangnam Technology and Software Events 2025\...   6.5
# 37  # Reverse-Acquihire Trend and Decibel Venture ...   6.5
# 38  # AI·ICT 기술·산업전망 컨퍼런스 and Jung-gu District\n\n...   4.0
